# %% [markdown]
# ### The notebook below demos connections to the AWS pamsdemo instance.... using the base (root) environment, Psycopg2, sql magic (%%sql), and geopandas library

# %% [markdown]
# Example connection to the AWS test DB using sql magic formatting below. Queries can then be run and formatted with '%%sql' used beforehand.
#
# The AWS db info:
# Host: pamsdemo.cbpltcizfdj7.us-west-1.rds.amazonaws.com
# Port: 5435
# username: postgres
# password: nitehawks1942
# db: oakpark

# %%
# %load_ext sql
conn= %sql postgresql://postgres:nitehawks1942@pamsdemo.cbpltcizfdj7.us-west-1.rds.amazonaws.com:5435/oakpark
conn #this variable setup is optional.. initally used for testing with geopandas...
# Out:
# 'Connected: postgres@oakpark'

# %%
# %%sql
#
# SELECT * FROM revenue.parkmobile_revenue
# LIMIT 20;
# Out:
#  * postgresql://postgres:***@pamsdemo.cbpltcizfdj7.us-west-1.rds.amazonaws.com:5435/oakpark
# 20 rows affected.
# [(441, None, 'Oakland, CA', datetime.datetime(2016, 7, 1, 10, 1), datetime.datetime(2016, 7, 1, 12, 1), 777418, datetime.datetime(2016, 7, 1, 10, 1), 'Yes', Decimal('4.35'), Decimal('4'), Decimal('0.35'), 1),
#  (441, None, 'Oakland, CA', datetime.datetime(2016, 7, 1, 10, 10), datetime.datetime(2016, 7, 1, 11, 40), 626819, datetime.datetime(2016, 7, 1, 10, 10), 'Yes', Decimal('3.35'), Decimal('3'), Decimal('0.35'), 2),
#  (441, None, 'Oakland, CA', datetime.datetime(2016, 7, 1, 10, 21), datetime.datetime(2016, 7, 1, 12, 21), 1167647, datetime.datetime(2016, 7, 1, 10, 21), 'Yes', Decimal('4.35'), Decimal('4'), Decimal('0.35'), 3),
#  (441, None, 'Oakland, CA', datetime.datetime(2016, 7, 1, 11, 53), datetime.datetime(2016, 7, 1, 12, 29), 1712289, datetime.datetime(2016, 7, 1, 11, 53), 'Yes', Decimal('1.55'), Decimal('1.2'), Decimal('0.35'), 4),
# ...

# %%
# %%sql
#
# SELECT * FROM public.rppzones
# Out:
#  * postgresql://postgres:***@pamsdemo.cbpltcizfdj7.us-west-1.rds.amazonaws.com:5435/oakpark
# 17 rows affected.
# [(1, 9, 'I', Decimal('6828.06448355'), Decimal('723332.369797'), '0106000020B30800000100000001030000000100000015000000C0CF1028B9155741A08D9E7D224F4041A0AC645CBE155741A02CFF10D94E40413070C9E701165741E04E7F55E84E4041F ... (426 characters truncated) ... 55741804DC9393C4D4041C02F44581715574160F94EF37C4D4041305D3F227015574120800F81974D4041F00311C054155741E0ABB998094F4041C0CF1028B9155741A08D9E7D224F4041'),
#  (2, 4, 'D', Decimal('11173.8053383'), Decimal('3839674.00281'), '0106000020B30800000100000001030000000100000017000000A0243409A3175741C07E79B2BE4E4041A016CD8CA5175741A0946626D24E4041D017C86734185741A0CF78C1B94F40413 ... (490 characters truncated) ... 85741C08B43AD7A4D404180EEA62B0C185741404EB5F9644D4041406AFCA80518574120E75F24CD4D4041901328935A185741A0C64854E24D4041A0243409A3175741C07E79B2BE4E4041'),
# ...

# %% [markdown]
# ### Example 1:
#
# What are the 10 most profitable parking meters in Oakland for Q4 2017 and 2018? What is there change year over year?

# %%
# %%sql
#
# SELECT meter_id, sub_area, totrev17q3, totrev18q3
# FROM public.parking_rev_qtr
# ORDER BY totrev18q3 DESC
# LIMIT 10;
# Out:
#  * postgresql://postgres:***@pamsdemo.cbpltcizfdj7.us-west-1.rds.amazonaws.com:5435/oakpark
# 10 rows affected.
# [('PLOT-1', 'Piedmont Lot', 14830.7, 20643.8),
#  ('GLOT-1', 'Grand Ave Lot', 12219.5, 17764.7),
#  ('GLOT-3', 'Grand Ave Lot', 15617.3, 17033.4),
#  ('PLOT-4', 'Piedmont Lot', 13544.8, 16877.9),
#  ('PLOT-2', 'Piedmont Lot', 11918.2, 15734.3),
#  ('L3200-5', 'Lakeshore Ave', 12896.0, 15632.7),
#  ('PLOT-3', 'Piedmont Lot', 13387.8, 15521.3),
#  ('L3300-1', 'Lakeshore Ave', 7404.2, 15101.1),
#  ('G3300-4', 'Grand Ave', 11098.3, 14792.3),
#  ('G600-4', 'Grand Ave', 10579.2, 14118.7)]

# %% [markdown]
# ### Incorporating pandas and numpy below to analyze the data... and matplotlib to display the top ten meter revenue.

# %%
import pandas as pd
import numpy as np

# %%
df = _.DataFrame()
df.describe()
# Out:
#          totrev17q3    totrev18q3
# count     10.000000     10.000000
# mean   12349.600000  16322.020000
# std     2333.302779   1877.386166
# min     7404.200000  14118.700000
# 25%    11303.275000  15206.150000
# 50%    12557.750000  15683.500000
# 75%    13505.550000  16994.525000
# max    15617.300000  20643.800000

# %%
df.head()
# Out:
#   meter_id       sub_area  totrev17q3  totrev18q3
# 0   PLOT-1   Piedmont Lot     14830.7     20643.8
# 1   GLOT-1  Grand Ave Lot     12219.5     17764.7
# 2   GLOT-3  Grand Ave Lot     15617.3     17033.4
# 3   PLOT-4   Piedmont Lot     13544.8     16877.9
# 4   PLOT-2   Piedmont Lot     11918.2     15734.3

# %% [markdown]
# ## Change the index to meter ID so that when the bar chart is created, it will be the x-axis:

# %%
df.set_index('meter_id', inplace = True)

# %%
df.head()
# Out:
#                sub_area  totrev17q3  totrev18q3
# meter_id
# PLOT-1     Piedmont Lot     14830.7     20643.8
# GLOT-1    Grand Ave Lot     12219.5     17764.7
# GLOT-3    Grand Ave Lot     15617.3     17033.4
# PLOT-4     Piedmont Lot     13544.8     16877.9
# PLOT-2     Piedmont Lot     11918.2     15734.3

# %%
# %matplotlib inline

# %% [markdown]
# '%matplotlib inline' -Allows you to see the plots created inside the notebook

# %%
df.plot.bar()

# %% [markdown]
# ### Example 2
#
# #### What is total parking meter revenue per quarter for 2018? What was the most profitable quarter?

# %%
# %%sql
#
# SELECT  sum(totrev18q1) as Q1, sum(totrev18q2) as Q2, sum(totrev18q3) as Q3, sum(totrev18q4) as Q4
# FROM public.parking_rev_qtr;
# Out:
#  * postgresql://postgres:***@pamsdemo.cbpltcizfdj7.us-west-1.rds.amazonaws.com:5435/oakpark
# 1 rows affected.
# [(3538485.77, 3637174.26, 4371346.15000001, 3460743.72999999)]

# %%
rev17 = _.DataFrame()

# %%
rev17.plot.bar()

# %% [markdown]
# #### Q3 2018 is the most profitable quarter with ~ $4,371,346 in revenue.
